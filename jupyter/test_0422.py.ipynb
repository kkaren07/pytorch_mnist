# %%
# !ls
# Out:
# #train.py#         data_mnist         train_mnist.py     vision
# __pycache__        load_data.py       train_tutorial.py  visual_data.py
# cifar_data.py      net.py             train_vgg.py
# data               test_0422.py.ipynb undo_train.py

# %%
# !python train_mnist.py 
# %matplotlib inline
# Out:
# /Users/karenkosaka/.pyenv/versions/3.6.4/lib/python3.6/site-packages/torchvision-0.2.3a0+ccbb322-py3.6.egg/torchvision/datasets/mnist.py:43: UserWarning: train_labels has been renamed targets
# tensor([5, 0, 4,  ..., 5, 6, 8])
# Traceback (most recent call last):
#   File "train_mnist.py", line 107, in <module>
#     main(epochs)
#   File "train_mnist.py", line 33, in main
#     for batch_idx, (images, labels) in enumerate(load_data.train_labels_error,0):
#   File "/Users/karenkosaka/.pyenv/versions/3.6.4/lib/python3.6/site-packages/torch/tensor.py", line 422, in __iter__
#     raise TypeError('iteration over a 0-d tensor')
# TypeError: iteration over a 0-d tensor

# %%
# !cat train_mnist.py
# Out:
# import argparse
# import numpy as np
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import DataLoader
# import torchvision
# import torchvision.transforms as transforms
# from net import Net
# import load_data
# import torch.optim as optim
# import matplotlib.pyplot as plt
#
# # def parser():
# #     parser = argparse.ArgumentParser(description='PyTorch MNIST')
# #     parser.add_argument('--epochs', '-e', type=int, default=2,
# #                         help='number of epochs to train (default: 2)')
# #     parser.add_argument('--lr', '-l', type=float, default=0.01,
# #                         help='learning rate (default: 0.01)')
# #     args = parser.parse_args()
# #     return args
#
# def main(epochs):
#     net = Net()
#     criterion = nn.CrossEntropyLoss()
#     optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
#     #pred_label=[]
#
#     #args = parser()
#
#     for epoch in range(epochs):
#         running_loss = 0.0
#         for batch_idx, (images, labels) in enumerate(load_data.trainloader):
#             # 勾配の初期化
#             optimizer.zero_grad()
#             # forward + backward + optimize
#             outputs = net(images)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()
#
#             # print statistics
#             running_loss += loss.item()
#             if i % 100 == 99:
#                 print('[%d, %5d] loss: %.3f' %
#                       (epoch + 1, i + 1, running_loss / 100))
#                 running_loss = 0.0
#
#         print('Finished Training')
#
#     torch.save(net.state_dict(), 'weight')
#
#
#     #the_model = TheModelClass(*args, **kwargs)
#     #the_model.load_state_dict(torch.load(weight))
#     # test
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for (images, labels) in load_data.testloader:
#             outputs = net(images)
#             _, predicted = torch.max(outputs.data, 1)
#             total += labels.size(0)
#             #if predicted==labels
#             correct += (predicted == labels).sum().item()
#             #imgshow(predicted)
#             #pred_label.append(predicted)
#
#
#     #total accuracy
#     print('Accuracy: %2d %%' % (100 * correct/total))
#
#     ## accuracy of each class
#     # class_correct = list(0. for i in range(10))
#     # class_total = list(0. for i in range(10))
#     # with torch.no_grad():
#     #     for data in load_data.testloader:
#     #         images, labels = data
#     #         outputs = net(images)
#     #         _, predicted = torch.max(outputs, 1)
#     #         c = (predicted == labels).squeeze()
#     #         for i in range(4):
#     #             label = labels[i]
#     #             class_correct[label] += c[i].item()
#     #             class_total[label] += 1
#     # for i in range(10):
#     #     print('Accuracy of %5s : %2d %%' % (
#     #         classes[i], 100 * class_correct[i] / class_total[i]))
#
#     print('Accuracy of the network on the 10000 test images: %d %%' % (
#         100 * correct / total))
#     imgshow(predicted)
#
# def imgshow(pred_label):
#     #img = images / 2 + 0.5     # unnormalize
#     #1batch from test_data
#     images, labels = iter(load_data.testloader).next()
#     npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
#     # [c, h, w] => [h, w, c]
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.axis('off')
#     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#
# if __name__ == '__main__':
#     epochs = 2
#     main(epochs)

# %%
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from net import Net
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline



def main():
    net = Net()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(1):
        running_loss = 0.0
        for i, (inputs, labels) in enumerate(load_data.trainloader, 0):
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # print statistics
            running_loss += loss.item()
            if i % 100 == 99:
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
                                      
        print('Finished Training')

    torch.save(net.state_dict(), 'weight')

    
    #the_model = TheModelClass(*args, **kwargs)
    #the_model.load_state_dict(torch.load(weight))
    # test
    correct = 0
    total = 0
    with torch.no_grad():
        for (images, labels) in load_data.testloader:
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            #if predicted==labels
            correct += (predicted == labels).sum().item()
            #imgshow(predicted)
            #pred_label.append(predicted)
            
            
    #total accuracy
    print('Accuracy: %2d %%' % (100 * correct/total))

    ## accuracy of each class
    # class_correct = list(0. for i in range(10))
    # class_total = list(0. for i in range(10))
    # with torch.no_grad():
    #     for data in load_data.testloader:
    #         images, labels = data
    #         outputs = net(images)
    #         _, predicted = torch.max(outputs, 1)
    #         c = (predicted == labels).squeeze()
    #         for i in range(4):
    #             label = labels[i]
    #             class_correct[label] += c[i].item()
    #             class_total[label] += 1
    # for i in range(10):
    #     print('Accuracy of %5s : %2d %%' % (
    #         classes[i], 100 * class_correct[i] / class_total[i]))
    
    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))
    imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    main()
# Out:
# [1,   100] loss: 2.146
# [1,   200] loss: 0.996
# [1,   300] loss: 0.619
# [1,   400] loss: 0.496
# [1,   500] loss: 0.414
# [1,   600] loss: 0.355
# Finished Training
# Accuracy: 89 %
# Accuracy of the network on the 10000 test images: 89 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cc15cfe3474d> in <module>
#      99
#     100 if __name__ == '__main__':
# --> 101     main()
#     102
#
# <ipython-input-14-cc15cfe3474d> in main()
#      85     print('Accuracy of the network on the 10000 test images: %d %%' % (
#      86         100 * correct / total))
# ---> 87     imgshow(predicted)
#      88
#      89 def imgshow(pred_label):
#
# <ipython-input-14-cc15cfe3474d> in imgshow(pred_label)
#      95     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#      96     plt.axis('off')
# ---> 97     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#      98     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#      99
#
# <ipython-input-14-cc15cfe3474d> in <genexpr>(.0)
#      95     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#      96     plt.axis('off')
# ---> 97     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#      98     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#      99
#
# NameError: name 'predicted' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x11c0fbae8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     564         else:
#     565             im, l, b, trans = self.make_image(
# --> 566                 renderer, renderer.get_image_magnification())
#     567             if im is not None:
#     568                 renderer.draw_image(gc, l, b, im)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     791         return self._make_image(
#     792             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 793             unsampled=unsampled)
#     794
#     795     def _check_unsampled_image(self, renderer):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     482             # (of int or float)
#     483             # or an RGBA array of re-sampled input
# --> 484             output = self.to_rgba(output, bytes=True, norm=False)
#     485             # output is now a correctly sized RGBA array of uint8
#     486
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     255                 if xx.dtype.kind == 'f':
#     256                     if norm and xx.max() > 1 or xx.min() < 0:
# --> 257                         raise ValueError("Floating point image RGB values "
#     258                                          "must be in the 0..1 range.")
#     259                     if bytes:
#
# ValueError: Floating point image RGB values must be in the 0..1 range.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     564         else:
#     565             im, l, b, trans = self.make_image(
# --> 566                 renderer, renderer.get_image_magnification())
#     567             if im is not None:
#     568                 renderer.draw_image(gc, l, b, im)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     791         return self._make_image(
#     792             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 793             unsampled=unsampled)
#     794
#     795     def _check_unsampled_image(self, renderer):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     482             # (of int or float)
#     483             # or an RGBA array of re-sampled input
# --> 484             output = self.to_rgba(output, bytes=True, norm=False)
#     485             # output is now a correctly sized RGBA array of uint8
#     486
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     255                 if xx.dtype.kind == 'f':
#     256                     if norm and xx.max() > 1 or xx.min() < 0:
# --> 257                         raise ValueError("Floating point image RGB values "
#     258                                          "must be in the 0..1 range.")
#     259                     if bytes:
#
# ValueError: Floating point image RGB values must be in the 0..1 range.

# %%
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from net import Net
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline



def main():
    net = Net()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(1):
        running_loss = 0.0
        for i, (inputs, labels) in enumerate(load_data.trainloader, 0):
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # print statistics
            running_loss += loss.item()
            if i % 100 == 99:
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
                                      
        print('Finished Training')

    torch.save(net.state_dict(), 'weight')

    
    #the_model = TheModelClass(*args, **kwargs)
    #the_model.load_state_dict(torch.load(weight))
    # test
    correct = 0
    total = 0
    with torch.no_grad():
        for (images, labels) in load_data.testloader:
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            #if predicted==labels
            correct += (predicted == labels).sum().item()
            #imgshow(predicted)
            #pred_label.append(predicted)
            
            
    #total accuracy
    print('Accuracy: %2d %%' % (100 * correct/total))

    ## accuracy of each class
    # class_correct = list(0. for i in range(10))
    # class_total = list(0. for i in range(10))
    # with torch.no_grad():
    #     for data in load_data.testloader:
    #         images, labels = data
    #         outputs = net(images)
    #         _, predicted = torch.max(outputs, 1)
    #         c = (predicted == labels).squeeze()
    #         for i in range(4):
    #             label = labels[i]
    #             class_correct[label] += c[i].item()
    #             class_total[label] += 1
    # for i in range(10):
    #     print('Accuracy of %5s : %2d %%' % (
    #         classes[i], 100 * class_correct[i] / class_total[i]))
    
    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))
    imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    main()
# Out:
# [1,   100] loss: 2.148
# [1,   200] loss: 0.972
# [1,   300] loss: 0.563
# [1,   400] loss: 0.477
# [1,   500] loss: 0.400
# [1,   600] loss: 0.330
# Finished Training
# Accuracy: 90 %
# Accuracy of the network on the 10000 test images: 90 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cc15cfe3474d> in <module>
#      99
#     100 if __name__ == '__main__':
# --> 101     main()
#     102
#
# <ipython-input-6-cc15cfe3474d> in main()
#      85     print('Accuracy of the network on the 10000 test images: %d %%' % (
#      86         100 * correct / total))
# ---> 87     imgshow(predicted)
#      88
#      89 def imgshow(pred_label):
#
# <ipython-input-6-cc15cfe3474d> in imgshow(pred_label)
#      95     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#      96     plt.axis('off')
# ---> 97     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#      98     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#      99
#
# <ipython-input-6-cc15cfe3474d> in <genexpr>(.0)
#      95     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#      96     plt.axis('off')
# ---> 97     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#      98     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#      99
#
# NameError: name 'predicted' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x10c0ea8c8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     564         else:
#     565             im, l, b, trans = self.make_image(
# --> 566                 renderer, renderer.get_image_magnification())
#     567             if im is not None:
#     568                 renderer.draw_image(gc, l, b, im)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     791         return self._make_image(
#     792             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 793             unsampled=unsampled)
#     794
#     795     def _check_unsampled_image(self, renderer):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     482             # (of int or float)
#     483             # or an RGBA array of re-sampled input
# --> 484             output = self.to_rgba(output, bytes=True, norm=False)
#     485             # output is now a correctly sized RGBA array of uint8
#     486
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     255                 if xx.dtype.kind == 'f':
#     256                     if norm and xx.max() > 1 or xx.min() < 0:
# --> 257                         raise ValueError("Floating point image RGB values "
#     258                                          "must be in the 0..1 range.")
#     259                     if bytes:
#
# ValueError: Floating point image RGB values must be in the 0..1 range.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     564         else:
#     565             im, l, b, trans = self.make_image(
# --> 566                 renderer, renderer.get_image_magnification())
#     567             if im is not None:
#     568                 renderer.draw_image(gc, l, b, im)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     791         return self._make_image(
#     792             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 793             unsampled=unsampled)
#     794
#     795     def _check_unsampled_image(self, renderer):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     482             # (of int or float)
#     483             # or an RGBA array of re-sampled input
# --> 484             output = self.to_rgba(output, bytes=True, norm=False)
#     485             # output is now a correctly sized RGBA array of uint8
#     486
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     255                 if xx.dtype.kind == 'f':
#     256                     if norm and xx.max() > 1 or xx.min() < 0:
# --> 257                         raise ValueError("Floating point image RGB values "
#     258                                          "must be in the 0..1 range.")
#     259                     if bytes:
#
# ValueError: Floating point image RGB values must be in the 0..1 range.

# %%
# !cat train_mnist.py
# Out:
# import numpy as np
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import DataLoader
# import torchvision
# import torchvision.transforms as transforms
# from model import TheModelClass
# import load_data
# import torch.optim as optim
# import matplotlib.pyplot as plt
#
# # def parser():
# #     parser = argparse.ArgumentParser(description='PyTorch MNIST')
# #     parser.add_argument('--epochs', '-e', type=int, default=2,
# #                         help='number of epochs to train (default: 2)')
# #     parser.add_argument('--lr', '-l', type=float, default=0.01,
# #                         help='learning rate (default: 0.01)')
# #     args = parser.parse_args()
# #     return args
#
# def train(epochs):
#     criterion = nn.CrossEntropyLoss()
#     optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
#     #pred_label=[]
#
#     #args = parser()
#
#     for epoch in range(epochs):
#         running_loss = 0.0
#         for batch_idx, (images, labels) in enumerate(load_data.trainloader):
#             # 勾配の初期化
#             optimizer.zero_grad()
#             # forward + backward + optimize
#             outputs = model(images)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()
#             running_loss += loss.item()
#             if i % 100 == 99:# print every 100 mini-batches
#                 print('[%d, %5d] loss: %.3f' %
#                       (epoch + 1, i + 1, running_loss / 100))
#                 running_loss = 0.0
#
#         print('Finished Training')
#     torch.save(model.state_dict(), 'weight.pt')
#
# def test():
#     model = TheModelClass(*args, **kwargs)
#     model.load_state_dict(torch.load(weight.pt))
#     # correct = 0
#     # total = 0
#     # with torch.no_grad():
#     #     for (images, labels) in load_data.testloader:
#     #         outputs = model(images)
#     #         _, predicted = torch.max(outputs.data, 1)
#     #         total += labels.size(0)
#     #         #if predicted==labels
#     #         correct += (predicted == labels).sum().item()
#     #         #imgshow(predicted)
#     #         #pred_label.append(predicted)
#
#
#
#     #accuracy of each class
#     class_correct = list(0. for i in range(10))
#     class_total = list(0. for i in range(10))
#     with torch.no_grad():
#         for data in load_data.testloader:
#             images, labels = data
#             outputs = model(images)
#             _, predicted = torch.max(outputs, 1)
#             c = (predicted == labels).squeeze()
#             for i in range(100):#range(batch_size)
#                 label = labels[i]
#                 class_correct[label] += c[i].item()
#                 class_total[label] += 1
#     for i in range(10):
#         print('Accuracy of %5s : %2d %%' % (
#             classes[i], 100 * class_correct[i] / class_total[i]))
#     #total accuracy
#     print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
#     #imgshow(predicted)
#
# def imgshow(pred_label):
#     #img = images / 2 + 0.5     # unnormalize
#     #1batch from test_data
#     images, labels = iter(load_data.testloader).next()
#     npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
#     # [c, h, w] => [h, w, c]
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.axis('off')
#     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#
# if __name__ == '__main__':
#     epochs = 2
#     model = TheModelClass()
#     test(epochs)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from model import TheModelClass
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt

# def parser():
#     parser = argparse.ArgumentParser(description='PyTorch MNIST')
#     parser.add_argument('--epochs', '-e', type=int, default=2,
#                         help='number of epochs to train (default: 2)')
#     parser.add_argument('--lr', '-l', type=float, default=0.01,
#                         help='learning rate (default: 0.01)')
#     args = parser.parse_args()
#     return args

def train(epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (images, labels) in enumerate(load_data.trainloader):
            # 勾配の初期化
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if i % 100 == 99:# print every 100 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
        
        print('Finished Training')
    torch.save(model.state_dict(), 'weight.pt')
       
def test():
    model = TheModelClass(*args, **kwargs)
    model.load_state_dict(torch.load(weight.pt))
    # correct = 0
    # total = 0
    # with torch.no_grad():
    #     for (images, labels) in load_data.testloader:
    #         outputs = model(images)
    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         #if predicted==labels
    #         correct += (predicted == labels).sum().item()
    #         #imgshow(predicted)
    #         #pred_label.append(predicted)
   
  

    #accuracy of each class
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in load_data.testloader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(100):#range(batch_size)
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1
    for i in range(10):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
    #total accuracy
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    #imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    epochs = 2
    model = TheModelClass()
    test(epochs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4c3728025654> in <module>
#      96 if __name__ == '__main__':
#      97     epochs = 2
# ---> 98     model = TheModelClass()
#      99     test(epochs)
#     100
#
# ~/itoh_lab/pytorch_mnist/model.py in __init__(self)
#       4 class TheModelClass(nn.Module):
#       5     def __init__(self):
# ----> 6         super(TheModelClass, self).__init__()
#       7         self.conv1 = nn.Conv2d(1, 32, 3) # 28x28x32 -> 26x26x32
#       8         self.conv2 = nn.Conv2d(32, 64, 3) # 26x26x64 -> 24x24x64
#
# NameError: name 'Net' is not defined

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from model import TheModelClass
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt

# def parser():
#     parser = argparse.ArgumentParser(description='PyTorch MNIST')
#     parser.add_argument('--epochs', '-e', type=int, default=2,
#                         help='number of epochs to train (default: 2)')
#     parser.add_argument('--lr', '-l', type=float, default=0.01,
#                         help='learning rate (default: 0.01)')
#     args = parser.parse_args()
#     return args

def train(epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (images, labels) in enumerate(load_data.trainloader):
            # 勾配の初期化
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if i % 100 == 99:# print every 100 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
        
        print('Finished Training')
    torch.save(model.state_dict(), 'weight.pt')
       
def test():
    model = TheModelClass(*args, **kwargs)
    model.load_state_dict(torch.load(weight.pt))
    # correct = 0
    # total = 0
    # with torch.no_grad():
    #     for (images, labels) in load_data.testloader:
    #         outputs = model(images)
    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         #if predicted==labels
    #         correct += (predicted == labels).sum().item()
    #         #imgshow(predicted)
    #         #pred_label.append(predicted)
   
  

    #accuracy of each class
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in load_data.testloader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(100):#range(batch_size)
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1
    for i in range(10):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
    #total accuracy
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    #imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    epochs = 2
    model = TheModelClass()
    test(epochs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4c3728025654> in <module>
#      96 if __name__ == '__main__':
#      97     epochs = 2
# ---> 98     model = TheModelClass()
#      99     test(epochs)
#     100
#
# ~/itoh_lab/pytorch_mnist/model.py in __init__(self)
#       4 class TheModelClass(nn.Module):
#       5     def __init__(self):
# ----> 6         super(TheModelClass, self).__init__()
#       7         self.conv1 = nn.Conv2d(1, 32, 3) # 28x28x32 -> 26x26x32
#       8         self.conv2 = nn.Conv2d(32, 64, 3) # 26x26x64 -> 24x24x64
#
# NameError: name 'Net' is not defined

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from model import TheModelClass
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt

# def parser():
#     parser = argparse.ArgumentParser(description='PyTorch MNIST')
#     parser.add_argument('--epochs', '-e', type=int, default=2,
#                         help='number of epochs to train (default: 2)')
#     parser.add_argument('--lr', '-l', type=float, default=0.01,
#                         help='learning rate (default: 0.01)')
#     args = parser.parse_args()
#     return args

def train(epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (images, labels) in enumerate(load_data.trainloader):
            # 勾配の初期化
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if batch_idx % 100 == 99:# print every 100 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, batch_idx + 1, running_loss / 100))
                running_loss = 0.0
        
        print('Finished Training')
        test()
    #torch.save(model.state_dict(), 'weight.pt')
       
def test():
    #model = TheModelClass(*args, **kwargs)
    #model.load_state_dict(torch.load(weight.pt))
    # correct = 0
    # total = 0
    # with torch.no_grad():
    #     for (images, labels) in load_data.testloader:
    #         outputs = model(images)
    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         #if predicted==labels
    #         correct += (predicted == labels).sum().item()
    #         #imgshow(predicted)
    #         #pred_label.append(predicted)
   
  

    #accuracy of each class
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in load_data.testloader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(100):#range(batch_size)
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1
    for i in range(10):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
    #total accuracy
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    #imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    epochs = 2
    model = TheModelClass()
    train(epochs)
# Out:
# [1,   100] loss: 2.201
# [1,   200] loss: 1.126
# [1,   300] loss: 0.540
# [1,   400] loss: 0.431
# [1,   500] loss: 0.374
# [1,   600] loss: 0.313
# Finished Training
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e846f9319ace> in <module>
#      98     epochs = 2
#      99     model = TheModelClass()
# --> 100     train(epochs)
#
# <ipython-input-4-e846f9319ace> in train(epochs)
#      44
#      45         print('Finished Training')
# ---> 46         test()
#      47     #torch.save(model.state_dict(), 'weight.pt')
#      48
#
# <ipython-input-4-e846f9319ace> in test()
#      79     for i in range(10):
#      80         print('Accuracy of %5s : %2d %%' % (
# ---> 81             classes[i], 100 * class_correct[i] / class_total[i]))
#      82     #total accuracy
#      83     print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
#
# NameError: name 'classes' is not defined

# %%
# !cat model.py
# Out:
# import torch.nn as nn
# import torch.nn.functional as F
#
# class TheModelClass(nn.Module):
#     def __init__(self):
#         super(TheModelClass, self).__init__()
#         self.conv1 = nn.Conv2d(1, 32, 3) # 28x28x32 -> 26x26x32
#         self.conv2 = nn.Conv2d(32, 64, 3) # 26x26x64 -> 24x24x64
#         self.pool = nn.MaxPool2d(2, 2) # 24x24x64 -> 12x12x64
#         self.dropout1 = nn.Dropout2d()
#         self.fc1 = nn.Linear(12 * 12 * 64, 128)
#         self.dropout2 = nn.Dropout2d()
#         self.fc2 = nn.Linear(128, 10)
#
#     def forward(self, x):
#         x = F.relu(self.conv1(x))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = self.dropout1(x)
#         x = x.view(-1, 12 * 12 * 64)
#         x = F.relu(self.fc1(x))
#         x = self.dropout2(x)
#         x = self.fc2(x)
#         return x

# %%
# !cat train_mnist.py
# Out:
# import numpy as np
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import DataLoader
# import torchvision
# import torchvision.transforms as transforms
# from model import TheModelClass
# import load_data
# import torch.optim as optim
# import matplotlib.pyplot as plt
#
# # def parser():
# #     parser = argparse.ArgumentParser(description='PyTorch MNIST')
# #     parser.add_argument('--epochs', '-e', type=int, default=2,
# #                         help='number of epochs to train (default: 2)')
# #     parser.add_argument('--lr', '-l', type=float, default=0.01,
# #                         help='learning rate (default: 0.01)')
# #     args = parser.parse_args()
# #     return args
#
# def train(epochs):
#     criterion = nn.CrossEntropyLoss()
#     optimizer = optim.SGD(model.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
#     #pred_label=[]
#
#     #args = parser()
#
#     for epoch in range(epochs):
#         running_loss = 0.0
#         for batch_idx, (images, labels) in enumerate(load_data.trainloader):
#             # 勾配の初期化
#             optimizer.zero_grad()
#             # forward + backward + optimize
#             outputs = model(images)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()
#             running_loss += loss.item()
#             if batch_idx % 100 == 99:# print every 100 mini-batches
#                 print('[%d, %5d] loss: %.3f' %
#                       (epoch + 1, batch_idx + 1, running_loss / 100))
#                 running_loss = 0.0
#
#         print('Finished Training')
#         test()
#     torch.save(model.state_dict(), 'weight.pt')
#
# def test():
#     model = TheModelClass(*args, **kwargs)
#     model.load_state_dict(torch.load(weight.pt))
#     # correct = 0
#     # total = 0
#     # with torch.no_grad():
#     #     for (images, labels) in load_data.testloader:
#     #         outputs = model(images)
#     #         _, predicted = torch.max(outputs.data, 1)
#     #         total += labels.size(0)
#     #         #if predicted==labels
#     #         correct += (predicted == labels).sum().item()
#     #         #imgshow(predicted)
#     #         #pred_label.append(predicted)
#
#
#
#     #accuracy of each class
#     class_correct = list(0. for i in range(10))
#     class_total = list(0. for i in range(10))
#     with torch.no_grad():
#         for data in load_data.testloader:
#             images, labels = data
#             outputs = model(images)
#             _, predicted = torch.max(outputs, 1)
#             c = (predicted == labels).squeeze()
#             for i in range(100):#range(batch_size)
#                 label = labels[i]
#                 class_correct[label] += c[i].item()
#                 class_total[label] += 1
#     for i in range(10):
#         print('Accuracy of %5s : %2d %%' % (
#             load_data.classes[i], 100 * class_correct[i] / class_total[i]))
#     #total accuracy
#     print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
#     #imgshow(predicted)
#
# def imgshow(pred_label):
#     #img = images / 2 + 0.5     # unnormalize
#     #1batch from test_data
#     images, labels = iter(load_data.testloader).next()
#     npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
#     # [c, h, w] => [h, w, c]
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.axis('off')
#     print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
#     #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
#
# if __name__ == '__main__':
#     epochs = 2
#     model = TheModelClass()
#     #train(epochs)
#     test()

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from model import TheModelClass
import load_data
import torch.optim as optim
import matplotlib.pyplot as plt

# def parser():
#     parser = argparse.ArgumentParser(description='PyTorch MNIST')
#     parser.add_argument('--epochs', '-e', type=int, default=2,
#                         help='number of epochs to train (default: 2)')
#     parser.add_argument('--lr', '-l', type=float, default=0.01,
#                         help='learning rate (default: 0.01)')
#     args = parser.parse_args()
#     return args

def train(epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(),lr=0.0005, momentum=0.99, nesterov=True)
    #pred_label=[]
    
    #args = parser()
    
    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (images, labels) in enumerate(load_data.trainloader):
            # 勾配の初期化
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if batch_idx % 100 == 99:# print every 100 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, batch_idx + 1, running_loss / 100))
                running_loss = 0.0
        
        print('Finished Training')
        test()
    torch.save(model.state_dict(), 'weight.pt')
       
def test():
    model = TheModelClass(*args, **kwargs)
    model.load_state_dict(torch.load(weight.pt))
    # correct = 0
    # total = 0
    # with torch.no_grad():
    #     for (images, labels) in load_data.testloader:
    #         outputs = model(images)
    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         #if predicted==labels
    #         correct += (predicted == labels).sum().item()
    #         #imgshow(predicted)
    #         #pred_label.append(predicted)
   
  

    #accuracy of each class
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in load_data.testloader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(100):#range(batch_size)
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1
    for i in range(10):
        print('Accuracy of %5s : %2d %%' % (
            load_data.classes[i], 100 * class_correct[i] / class_total[i]))
    #total accuracy
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    #imgshow(predicted)

def imgshow(pred_label):
    #img = images / 2 + 0.5     # unnormalize
    #1batch from test_data
    images, labels = iter(load_data.testloader).next()
    npimg =  torchvision.utils.make_grid(images, nrow=10, padding=1).numpy()
    # [c, h, w] => [h, w, c]
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    print(' '.join('%s' % load_data.classes[predicted[j]] for j in range(100)))
    #print('pred:%d' % (load_data.classes[pled_label[j]] for j in range(100)), 'ans:%d'%(load_data.classes[labels[i]] for i in range(100)))
    
if __name__ == '__main__':
    epochs = 2
    model = TheModelClass()
    #train(epochs)
    test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-25456e17b0bf> in <module>
#      99     model = TheModelClass()
#     100     #train(epochs)
# --> 101     test()
#     102
#
# <ipython-input-6-25456e17b0bf> in test()
#      48
#      49 def test():
# ---> 50     model = TheModelClass(*args, **kwargs)
#      51     model.load_state_dict(torch.load(weight.pt))
#      52     # correct = 0
#
# NameError: name 'args' is not defined

# %%
# !python train_mnist.py
# Out:
# /Users/karenkosaka/.pyenv/versions/3.6.4/lib/python3.6/site-packages/torchvision-0.2.3a0+ccbb322-py3.6.egg/torchvision/datasets/mnist.py:43: UserWarning: train_labels has been renamed targets
# tensor([5, 0, 4,  ..., 5, 6, 8])
# Accuracy of     0 : 98 %
# Accuracy of     1 : 98 %
# Accuracy of     2 : 93 %
# Accuracy of     3 : 90 %
# Accuracy of     4 : 94 %
# Accuracy of     5 : 90 %
# Accuracy of     6 : 97 %
# Accuracy of     7 : 92 %
# Accuracy of     8 : 89 %
# Accuracy of     9 : 94 %
# Accuracy of the network on the 10000 test images: 93 %
